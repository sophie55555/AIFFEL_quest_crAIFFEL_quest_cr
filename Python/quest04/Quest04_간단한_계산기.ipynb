# %% [markdown]
# <a href="https://colab.research.google.com/github/sophie55555/AIFFEL_quest_crAIFFEL_quest_cr/blob/main/Quest_04_%EA%B0%84%EB%8B%A8%ED%95%9C_%EA%B3%84%EC%82%B0%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math as m

def calculator():
    print("간단한 계산기")
    print("사용할 수 있는 연산: +, -, *, **, /")



    try:
        # 숫자 입력 받기
        num1 = float(input("첫 번째 숫자를 입력하세요: "))
        operator = input("연산자를 입력하세요 (+, -, *, **, /): ")
        num2 = float(input("두 번째 숫자를 입력하세요: "))
    except ValueError:


def get_integer_input(prompt):
    while True:
        try:
            value = int(input(prompt))  # 사용자로부터 정수를 입력 받음
            return value  # 정수가 입력되면 그 값을 반환
        except ValueError:
            # ValueError가 발생하면 잘못된 입력이므로 메시지를 출력하고 다시 입력받음
            print("잘못된 입력입니다. 정수를 입력해주세요.")





        # 연산 수행
        if operator == '+':
            result = num1 + num2
        elif operator == '-':
            result = num1 - num2
        elif operator == '*':
            result = num1 * num2
        elif operator == '**':
            result = num1 ** num2
        elif operator == '/':
            if num2 == 0:
                raise ZeroDivisionError("0으로 나눌 수 없습니다.")
            result = num1 / num2
        else:
            print("올바르지 않은 연산자입니다. 프로그램을 종료합니다.")
            return

        print(f"결과: {num1} {operator} {num2} = {result}")


    except ZeroDivisionError as e:
        print(e)
    except Exception as e:
        print(f"예상치 못한 오류가 발생했습니다: {e}")

# 계산기 실행
calculator()

# %%
import math  # math 모듈을 임포트하여 제곱 연산에 사용

# 정수를 입력받는 함수
def get_integer_input(prompt):
    while True:
        try:
            value = int(input(prompt))  # 사용자로부터 정수를 입력 받음
            return value  # 정수가 입력되면 그 값을 반환
        except ValueError:
            # ValueError가 발생하면 잘못된 입력이므로 메시지를 출력하고 다시 입력받음
            print("잘못된 입력입니다. 정수를 입력해주세요.")

# 연산자를 입력받는 함수
def get_operator_input():
    while True:
        operator = input("연산자를 입력하세요 (+, -, *, /, **): ")  # 사용자로부터 연산자 입력 받기
        if operator in ['+', '-', '*', '/', '**']:  # 입력된 연산자가 지원되는 연산자인지 확인
            return operator  # 올바른 연산자일 경우 그 값을 반환
        else:
            # 지원되지 않는 연산자일 경우 오류 메시지를 출력하고 다시 입력 받음
            print("지원하지 않는 연산자입니다. +, -, *, /, **만 입력 가능합니다.")

# 계산을 수행하는 함수
def calculate(num1, num2, operator):
    try:
        if operator == '+':  # 덧셈 연산
            return num1 + num2
        elif operator == '-':  # 뺄셈 연산
            return num1 - num2
        elif operator == '*':  # 곱셈 연산
            return num1 * num2
        elif operator == '/':  # 나눗셈 연산
            if num2 == 0:  # 두 번째 숫자가 0이면 ZeroDivisionError 발생
                raise ZeroDivisionError("0으로 나눌 수 없습니다.")  # 0으로 나눌 수 없다는 오류 메시지 출력
            return num1 / num2  # 나눗셈 결과 반환
        elif operator == '**':  # 제곱 연산
            return math.pow(num1, num2)  # math.pow를 사용하여 제곱 계산
    except ZeroDivisionError as e:
        # ZeroDivisionError가 발생하면 오류 메시지 출력
        print(f"오류: {e}")
        return None  # 오류 발생 시 None을 반환

# 메인 계산기 로직
def main():
    while True:
        # 첫 번째 정수 입력 받기
        num1 = get_integer_input("첫 번째 정수를 입력하세요: ")

        # 연산자 입력 받기
        operator = get_operator_input()

        # 두 번째 정수 입력 받기
        num2 = get_integer_input("두 번째 정수를 입력하세요: ")

        # 계산 수행
        result = calculate(num1, num2, operator)

        if result is not None:  # 결과가 None이 아니라면 계산 결과 출력
            print(f"결과: {num1} {operator} {num2} = {result}")

        # 계속 계산할지 여부 확인
        continue_calculation = input("계속 계산하시겠습니까? (y/n): ")
        if continue_calculation.lower() != 'y':  # 'y'가 아니면 종료
            print("계산기를 종료합니다.")
            break  # 반복문 종료

# 프로그램 실행
main()
# Out:
# 첫 번째 정수를 입력하세요: 1
# 연산자를 입력하세요 (+, -, *, /, **): +
# 두 번째 정수를 입력하세요: 10
# 결과: 1 + 10 = 11
# 계속 계산하시겠습니까? (y/n): y

# %%
# version3
import math as m

def calculator():
    print("간단한 계산기")
    print("사용할 수 있는 연산: +, -, *, **, /")

    try:
        # 숫자 입력 받기
        num1 = float(input("첫 번째 숫자를 입력하세요: "))
        operator = input("연산자를 입력하세요 (+, -, *, **, /): ")
        num2 = float(input("두 번째 숫자를 입력하세요: "))

        # 연산 수행
        if operator == '+':
            result = num1 + num2
        elif operator == '-':
            result = num1 - num2
        elif operator == '*':
            result = num1 * num2
        elif operator == '**':
            result = num1 ** num2
        elif operator == '/':
            if num2 == 0:
                raise ZeroDivisionError("0으로 나눌 수 없습니다.")
            result = num1 / num2
        else:
            print("올바르지 않은 연산자입니다. 프로그램을 종료합니다.")
            return

        print(f"결과: {num1} {operator} {num2} = {result}")

    except ValueError:
        print("잘못된 입력입니다. 숫자를 입력해주세요.")
    except ZeroDivisionError as e:
        print(e)
    except Exception as e:
        print(f"예상치 못한 오류가 발생했습니다: {e}")

def get_integer_input(prompt):
    while True:
        try:
            value = int(input(prompt))  # 사용자로부터 정수를 입력 받음
            return value  # 정수가 입력되면 그 값을 반환
        except ValueError:
            # ValueError가 발생하면 잘못된 입력이므로 메시지를 출력하고 다시 입력받음
            print("잘못된 입력입니다. 정수를 입력해주세요.")

# 계산기 실행
calculator()

# %%
#version4

import math as m

def calculator():
    print("간단한 계산기")
    print("사용할 수 있는 연산: +, -, *, **, /")

    def get_number_input(prompt):
        """숫자 입력을 받을 때까지 반복"""
        while True:
            try:
                return float(input(prompt))  # 숫자를 입력받아 반환
            except ValueError:
                print("잘못된 입력입니다. 숫자를 입력해주세요.")

    num1 = get_number_input("첫 번째 숫자를 입력하세요: ")

    while True:
        operator = input("연산자를 입력하세요 (+, -, *, **, /): ")
        if operator in ['+', '-', '*', '**', '/']:
            break
        print("잘못된 연산자입니다. 사용할 수 있는 연산: +, -, *, **, /")

    num2 = get_number_input("두 번째 숫자를 입력하세요: ")

    # 연산 수행
    try:
        if operator == '+':
            result = num1 + num2
        elif operator == '-':
            result = num1 - num2
        elif operator == '*':
            result = num1 * num2
        elif operator == '**':
            result = num1 ** num2
        elif operator == '/':
            if num2 == 0:
                raise ZeroDivisionError("0으로 나눌 수 없습니다.")
            result = num1 / num2

        print(f"결과: {num1} {operator} {num2} = {result}")

    except ZeroDivisionError as e:
        print(e)
    except Exception as e:
        print(f"예상치 못한 오류가 발생했습니다: {e}")

        # 계속 계산할지 여부 확인
    finally:
        continue_calculation = input("계속 계산하시겠습니까? (y/n): ")
        if continue_calculation.lower() != 'y':  # 'y'가 아니면 종료
            print("계산기를 종료합니다.")
            break

# 계산기 실행
calculator()

# %%
#version5

import math as m

def calculator():
    print("Quest 04 간단한 계산기")
    print("사용할 수 있는 연산: +, -, *, **, /")

    def get_number_input(prompt):
        """숫자 입력을 받을 때까지 반복"""
        while True:
            try:
                return float(input(prompt))  # 숫자를 입력받아 반환
            except ValueError: # ValueError가 발생하면 잘못된 입력이므로 메시지를 출력하고 다시 입력받음
                print("잘못된 입력입니다. 숫자를 입력해주세요.")

    while True:  # 계산 루프 시작
        num1 = get_number_input("첫 번째 숫자를 입력하세요: ")

        while True:
            operator = input("연산자를 입력하세요 (+, -, *, **, /): ")
            if operator in ['+', '-', '*', '**', '/']:
                break
            print("잘못된 연산자입니다. 사용할 수 있는 연산: +, -, *, **, /")

        num2 = get_number_input("두 번째 숫자를 입력하세요: ")

        # 연산 수행. 메인 계산기 로직
        try:
            if operator == '+':
                result = num1 + num2
            elif operator == '-':
                result = num1 - num2
            elif operator == '*':
                result = num1 * num2
            elif operator == '**':
                result = num1 ** num2
            elif operator == '/':
                if num2 == 0: # 두 번째 숫자가 0이면 ZeroDivisionError 발생
                    raise ZeroDivisionError("0으로 나눌 수 없습니다.")# 0으로 나눌 수 없다는 오류 메시지 출력
                result = num1 / num2

            print(f"결과: {num1} {operator} {num2} = {result}")

        except ZeroDivisionError as e:
            print(e)
        except Exception as e:
            print(f"예상치 못한 오류가 발생했습니다: {e}")

        # 계속 계산할지 여부 확인
        continue_calculation = input("계속 계산하시겠습니까? (y/n): ")
        if continue_calculation.lower() != 'y':  # 'y'가 아니면 종료
            print("계산기를 종료합니다.")
            break

# 계산기 실행
calculator()
# Out:
# 간단한 계산기
# 사용할 수 있는 연산: +, -, *, **, /
# 첫 번째 숫자를 입력하세요: ㄴ
# 잘못된 입력입니다. 숫자를 입력해주세요.
# 첫 번째 숫자를 입력하세요: 1
# 연산자를 입력하세요 (+, -, *, **, /): ㅇ
# 잘못된 연산자입니다. 사용할 수 있는 연산: +, -, *, **, /
# 연산자를 입력하세요 (+, -, *, **, /): 7
# 잘못된 연산자입니다. 사용할 수 있는 연산: +, -, *, **, /
# 연산자를 입력하세요 (+, -, *, **, /): 1
# 잘못된 연산자입니다. 사용할 수 있는 연산: +, -, *, **, /
# 연산자를 입력하세요 (+, -, *, **, /): -
# 두 번째 숫자를 입력하세요: 1
# 결과: 1.0 - 1.0 = 0.0
# 계속 계산하시겠습니까? (y/n): y
# 첫 번째 숫자를 입력하세요: 1
# 연산자를 입력하세요 (+, -, *, **, /): +1
# 잘못된 연산자입니다. 사용할 수 있는 연산: +, -, *, **, /
# 연산자를 입력하세요 (+, -, *, **, /): +
# 두 번째 숫자를 입력하세요: 2
# 결과: 1.0 + 2.0 = 3.0
# 계속 계산하시겠습니까? (y/n): n
# 계산기를 종료합니다.

# %% [markdown]
# 회고
# 고명지:
# finally를 적용할 경우 break를 동시에 사용할 수 없다는 것을 배웠음.
# 각 루프?에 함수를 적용하고 예외처리를 하며 다양한 명령어를 적용 실행하며 버전 5까지 진행하였습니다.
#
# 백승호:
# 간단한 계산기가 아니었다.
# 구상한 계산기의 로직이 생각보다 더 복잡해졌으며, 퀘스트 조건을 하나하나 추가할때마다 전체 로직을 변경해야 하는 문제도 발생하였다. 팀원이 3명이기에 마이크를 잡기가 쉽지는 않았지만, 팀원이 3명이기에 핵심 로직 검색 및 아이디어 제안이 다양하게 나올 수 있었다. 계산기의 로직은 각 문자열을 입력받는것, 필요한 함수 등은 예상할 수 있었지만 문법에 대한 에러 이슈로 gpt의 도움을 받아 버젼5에서 완성할 수 있었다.
#
# 이지선:
# 전체적인 흐름에 대해서 파악하는게 먼저였고 흐름에 맞게 시작하는 부분에 어려움이 있었다. ai의 도움을 받아 진행했고 퀘스트에 맞춰 전체적인 코드를 수정해서 진행하였다. ai가 제시한 코드와 작성한 코드에 차이를 확인하고 문제가 된 부분에 있어 도움을 많이 받을수 밖에 없었지만 서로 소통하고 문제를 해결해나가는 모습이 좋았다.
